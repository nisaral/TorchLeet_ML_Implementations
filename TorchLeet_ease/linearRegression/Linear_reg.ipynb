# %%
import torch 
import torch.nn as nn
import torch.optim as optim

#set a random seed for reproducibility 
torch.manual_seed(42)
#generating synthetic data:100 data points with one feature,values between 0 and 10
X=torch.rand(100,1)*10
# generating targets with a linear relationship (y=2*X+3) plus some random noise 
y=2*X+3+torch.rand(100,1)
#define the Linear Regression model by subclassing nn.Module
class LinearRegressionModel(nn.Module):
    def __init__(self):
        #call the parent class (nn.Module) constructor
        super(LinearRegressionModel,self).__init__()
        #lets define a linear layer:this layer maps 1 input feature to 1 output (y=w*X+b)
        self.linear=nn.Linear(in_features=1,out_features=1)
    def forward(self,x):
        #define the forward pass: pass input through the linear layer
        return self.linear(x)
model=LinearRegressionModel() #lets instantiate the model we just made
#define the loss function:Mean Squared Error(MSE)
criterion=nn.MSELoss()
#define the optimizer: Stochastic GRadient Descent (SGD)with learning rate of 0.01
optimizer=optim.SGD(model.parameters(),lr=0.01)
#training loop for 1000 epochs
epochs=1000
for epoch in range (epochs):
    #start with forward pass:compute predictions 
    predictions =model(X)
    #calculate the loss between the predictions and the actual targets
    loss=criterion(predictions,y)
    #backward pass:zero out old gradients to prevent accumulation
    loss.backward()
    #update the model parameters with the optimizer 
    optimizer.step()
    #log progress every 100 epochs 
    if (epochs+1)%100==0:
        printf(f"epoch [{epoch+1}/{epochs}],loss:{loss.item():.4f}")
    #extract and diplay learned parameters (weights and bias)
    [w,b]=model.linear.parameters()
    print(f"Learned weight:{w.item():.4f},learned bias:{b.item():.4f}")
    #lets test this model on new data points
    X_test=torch.tensor([[4.0],[7.0]])
    #disable gradient computation for inference 
    with torch.no_grad():
        #now we calculate the predictions for test data
        predictions=model(X_test)
        print(f"Predictions for {X_test.tolist()}:{predictions.tolist()}")
# Out:
# Learned weight:1.5356,learned bias:0.0075
# Predictions for [[4.0], [7.0]]:[[6.150079727172852], [10.75699520111084]]
# Learned weight:4.6642,learned bias:0.5010
# Predictions for [[4.0], [7.0]]:[[19.157819747924805], [33.15043640136719]]
# Learned weight:6.2242,learned bias:0.7787
# Predictions for [[4.0], [7.0]]:[[25.675493240356445], [44.348060607910156]]
# Learned weight:5.0888,learned bias:0.6743
# Predictions for [[4.0], [7.0]]:[[21.029407501220703], [36.29576873779297]]
# Learned weight:2.0680,learned bias:0.3068
# Predictions for [[4.0], [7.0]]:[[8.578960418701172], [14.783087730407715]]
# Learned weight:-0.6737,learned bias:-0.0047
# Predictions for [[4.0], [7.0]]:[[-2.699437379837036], [-4.720501899719238]]
# Learned weight:-1.1742,learned bias:0.0289
# Predictions for [[4.0], [7.0]]:[[-4.668028831481934], [-8.1907377243042]]
# Learned weight:0.9153,learned bias:0.4586
# Predictions for [[4.0], [7.0]]:[[4.119729995727539], [6.865606784820557]]
# Learned weight:4.0797,learned bias:1.0601
# Predictions for [[4.0], [7.0]]:[[17.378700256347656], [29.617658615112305]]
# Learned weight:6.0292,learned bias:1.4950
# Predictions for [[4.0], [7.0]]:[[25.611989974975586], [43.69972229003906]]
# Learned weight:5.3468,learned bias:1.5535
# Predictions for [[4.0], [7.0]]:[[22.940650939941406], [38.98100662231445]]
# Learned weight:2.5067,learned bias:1.3048
# Predictions for [[4.0], [7.0]]:[[11.331441879272461], [18.851417541503906]]
# Learned weight:-0.4662,learned bias:1.0469
# Predictions for [[4.0], [7.0]]:[[-0.8178240060806274], [-2.2163596153259277]]
# Learned weight:-1.4524,learned bias:1.0916
# Predictions for [[4.0], [7.0]]:[[-4.7179718017578125], [-9.075157165527344]]
# Learned weight:0.2376,learned bias:1.5398
# Predictions for [[4.0], [7.0]]:[[2.4903736114501953], [3.203291893005371]]
# Learned weight:3.3680,learned bias:2.2082
# Predictions for [[4.0], [7.0]]:[[15.680150985717773], [25.784122467041016]]
# Learned weight:5.6661,learned bias:2.7604
# Predictions for [[4.0], [7.0]]:[[25.424819946289062], [42.42312240600586]]
# Learned weight:5.4572,learned bias:2.9484
# Predictions for [[4.0], [7.0]]:[[24.777362823486328], [41.149105072021484]]
# Learned weight:2.8691,learned bias:2.7898
# Predictions for [[4.0], [7.0]]:[[14.266093254089355], [22.87328338623047]]
# Learned weight:-0.2602,learned bias:2.5550
# Predictions for [[4.0], [7.0]]:[[1.514400839805603], [0.7339507341384888]]
# Learned weight:-1.7034,learned bias:2.5714
# Predictions for [[4.0], [7.0]]:[[-4.242066383361816], [-9.352151870727539]]
# Learned weight:-0.4463,learned bias:2.9875
# Predictions for [[4.0], [7.0]]:[[1.2022782564163208], [-0.1366710662841797]]
# Learned weight:2.5832,learned bias:3.6655
# Predictions for [[4.0], [7.0]]:[[13.998113632202148], [21.747587203979492]]
# Learned weight:5.1825,learned bias:4.2791
# Predictions for [[4.0], [7.0]]:[[25.009214401245117], [40.556800842285156]]
# Learned weight:5.4587,learned bias:4.5480
# Predictions for [[4.0], [7.0]]:[[26.38263702392578], [42.75865173339844]]
# Learned weight:3.1895,learned bias:4.4382
# Predictions for [[4.0], [7.0]]:[[17.19601058959961], [26.764387130737305]]
# Learned weight:-0.0164,learned bias:4.1861
# Predictions for [[4.0], [7.0]]:[[4.120569229125977], [4.071437835693359]]
# Learned weight:-1.8761,learned bias:4.1274
# Predictions for [[4.0], [7.0]]:[[-3.376919746398926], [-9.005180358886719]]
# Learned weight:-1.0745,learned bias:4.4553
# Predictions for [[4.0], [7.0]]:[[0.1573352813720703], [-3.066108226776123]]
# Learned weight:1.7903,learned bias:5.0803
# Predictions for [[4.0], [7.0]]:[[12.241640090942383], [17.612632751464844]]
# Learned weight:4.6372,learned bias:5.6945
# Predictions for [[4.0], [7.0]]:[[24.2432918548584], [38.15485382080078]]
# Learned weight:5.3987,learned bias:5.9920
# Predictions for [[4.0], [7.0]]:[[27.58668327331543], [43.78272247314453]]
# Learned weight:3.5081,learned bias:5.8881
# Predictions for [[4.0], [7.0]]:[[19.920372009277344], [30.444595336914062]]
# Learned weight:0.3070,learned bias:5.5800
# Predictions for [[4.0], [7.0]]:[[6.807895660400391], [7.7288312911987305]]
# Learned weight:-1.9194,learned bias:5.4041
# Predictions for [[4.0], [7.0]]:[[-2.273578643798828], [-8.031839370727539]]
# Learned weight:-1.5857,learned bias:5.5936
# Predictions for [[4.0], [7.0]]:[[-0.7491941452026367], [-5.506320476531982]]
# Learned weight:1.0536,learned bias:6.1104
# Predictions for [[4.0], [7.0]]:[[10.324955940246582], [13.485888481140137]]
# Learned weight:4.0874,learned bias:6.6717
# Predictions for [[4.0], [7.0]]:[[23.021137237548828], [35.28322219848633]]
# Learned weight:5.3220,learned bias:6.9534
# Predictions for [[4.0], [7.0]]:[[28.241201400756836], [44.20707321166992]]
# Learned weight:3.8593,learned bias:6.8224
# Predictions for [[4.0], [7.0]]:[[22.259540557861328], [33.83737564086914]]
# Learned weight:0.7425,learned bias:6.4324
# Predictions for [[4.0], [7.0]]:[[9.402305603027344], [11.629762649536133]]
# Learned weight:-1.7941,learned bias:6.1125
# Predictions for [[4.0], [7.0]]:[[-1.063948631286621], [-6.4463114738464355]]
# Learned weight:-1.9319,learned bias:6.1310
# Predictions for [[4.0], [7.0]]:[[-1.5966005325317383], [-7.3923234939575195]]
# Learned weight:0.4242,learned bias:6.5017
# Predictions for [[4.0], [7.0]]:[[8.198539733886719], [9.471176147460938]]
# Learned weight:3.5774,learned bias:6.9740
# Predictions for [[4.0], [7.0]]:[[21.28369140625], [32.01593017578125]]
# Learned weight:5.2593,learned bias:7.2133
# Predictions for [[4.0], [7.0]]:[[28.250429153442383], [44.028263092041016]]
# Learned weight:4.2612,learned bias:7.0412
# Predictions for [[4.0], [7.0]]:[[24.085935592651367], [36.86946487426758]]
# Learned weight:1.3035,learned bias:6.5642
# Predictions for [[4.0], [7.0]]:[[11.778079986572266], [15.688491821289062]]
# Learned weight:-1.4826,learned bias:6.0969
# Predictions for [[4.0], [7.0]]:[[0.1666717529296875], [-4.280987739562988]]
# Learned weight:-2.0875,learned bias:5.9361
# Predictions for [[4.0], [7.0]]:[[-2.413811206817627], [-8.676218032836914]]
# Learned weight:-0.0689,learned bias:6.1474
# Predictions for [[4.0], [7.0]]:[[5.871931552886963], [5.665360450744629]]
# Learned weight:3.1305,learned bias:6.5183
# Predictions for [[4.0], [7.0]]:[[19.040239334106445], [28.431697845458984]]
# Learned weight:5.2201,learned bias:6.7114
# Predictions for [[4.0], [7.0]]:[[27.591873168945312], [43.25224304199219]]
# Learned weight:4.7091,learned bias:6.5072
# Predictions for [[4.0], [7.0]]:[[25.343738555908203], [39.471153259277344]]
# Learned weight:1.9783,learned bias:5.9625
# Predictions for [[4.0], [7.0]]:[[13.87571907043457], [19.810632705688477]]
# Learned weight:-0.9938,learned bias:5.3700
# Predictions for [[4.0], [7.0]]:[[1.39467191696167], [-1.5867924690246582]]
# Learned weight:-2.0539,learned bias:5.0480
# Predictions for [[4.0], [7.0]]:[[-3.1675257682800293], [-9.329187393188477]]
# Learned weight:-0.4225,learned bias:5.1125
# Predictions for [[4.0], [7.0]]:[[3.4227004051208496], [2.1553492546081543]]
# Learned weight:2.7454,learned bias:5.3938
# Predictions for [[4.0], [7.0]]:[[16.375362396240234], [24.61153793334961]]
# Learned weight:5.1906,learned bias:5.5595
# Predictions for [[4.0], [7.0]]:[[26.321956634521484], [41.893829345703125]]
# Learned weight:5.1748,learned bias:5.3539
# Predictions for [[4.0], [7.0]]:[[26.053279876708984], [41.577796936035156]]
# Learned weight:2.7304,learned bias:4.7829
# Predictions for [[4.0], [7.0]]:[[15.704336166381836], [23.89539909362793]]
# Learned weight:-0.3631,learned bias:4.1101
# Predictions for [[4.0], [7.0]]:[[2.6575238704681396], [1.5681216716766357]]
# Learned weight:-1.8586,learned bias:3.6679
# Predictions for [[4.0], [7.0]]:[[-3.7662765979766846], [-9.34194278717041]]
# Learned weight:-0.6576,learned bias:3.6197
# Predictions for [[4.0], [7.0]]:[[0.9892950057983398], [-0.9835011959075928]]
# Learned weight:2.3993,learned bias:3.8424
# Predictions for [[4.0], [7.0]]:[[13.4395751953125], [20.637481689453125]]
# Learned weight:5.1373,learned bias:4.0161
# Predictions for [[4.0], [7.0]]:[[24.565256118774414], [39.977088928222656]]
# Learned weight:5.6110,learned bias:3.8551
# Predictions for [[4.0], [7.0]]:[[26.299118041992188], [43.13213348388672]]
# Learned weight:3.5036,learned bias:3.3136
# Predictions for [[4.0], [7.0]]:[[17.328048706054688], [27.838916778564453]]
# Learned weight:0.3545,learned bias:2.6198
# Predictions for [[4.0], [7.0]]:[[4.037713050842285], [5.101163864135742]]
# Learned weight:-1.5480,learned bias:2.1125
# Predictions for [[4.0], [7.0]]:[[-4.079514503479004], [-8.72353458404541]]
# Learned weight:-0.8123,learned bias:1.9982
# Predictions for [[4.0], [7.0]]:[[-1.2508717775344849], [-3.687659740447998]]
# Learned weight:2.0556,learned bias:2.2032
# Predictions for [[4.0], [7.0]]:[[10.425507545471191], [16.592267990112305]]
# Learned weight:5.0156,learned bias:2.4275
# Predictions for [[4.0], [7.0]]:[[22.489805221557617], [37.536537170410156]]
# Learned weight:5.9609,learned bias:2.3613
# Predictions for [[4.0], [7.0]]:[[26.204870223999023], [44.08753204345703]]
# Learned weight:4.2329,learned bias:1.9084
# Predictions for [[4.0], [7.0]]:[[18.84001922607422], [31.538700103759766]]
# Learned weight:1.0947,learned bias:1.2562
# Predictions for [[4.0], [7.0]]:[[5.635130405426025], [8.91933822631836]]
# Learned weight:-1.1772,learned bias:0.7413
# Predictions for [[4.0], [7.0]]:[[-3.967437505722046], [-7.499026298522949]]
# Learned weight:-0.9305,learned bias:0.6086
# Predictions for [[4.0], [7.0]]:[[-3.1132612228393555], [-5.904664516448975]]
# Learned weight:1.6749,learned bias:0.8352
# Predictions for [[4.0], [7.0]]:[[7.5348992347717285], [12.559693336486816]]
# Learned weight:4.7816,learned bias:1.1477
# Predictions for [[4.0], [7.0]]:[[20.273971557617188], [34.6186637878418]]
# Learned weight:6.1703,learned bias:1.2195
# Predictions for [[4.0], [7.0]]:[[25.900604248046875], [44.411434173583984]]
# Learned weight:4.8561,learned bias:0.9058
# Predictions for [[4.0], [7.0]]:[[20.33014488220215], [34.898399353027344]]
# Learned weight:1.7965,learned bias:0.3485
# Predictions for [[4.0], [7.0]]:[[7.534387111663818], [12.923807144165039]]
# Learned weight:-0.7973,learned bias:-0.1256
# Predictions for [[4.0], [7.0]]:[[-3.314666748046875], [-5.706435203552246]]
# Learned weight:-1.0503,learned bias:-0.2395
# Predictions for [[4.0], [7.0]]:[[-4.4408860206604], [-7.5919013023376465]]
# Learned weight:1.2271,learned bias:0.0352
# Predictions for [[4.0], [7.0]]:[[4.943741798400879], [8.625142097473145]]
# Learned weight:4.4036,learned bias:0.4581
# Predictions for [[4.0], [7.0]]:[[18.072500228881836], [31.283281326293945]]
# Learned weight:6.1993,learned bias:0.6931
# Predictions for [[4.0], [7.0]]:[[25.490459442138672], [44.088504791259766]]
# Learned weight:5.3260,learned bias:0.5501
# Predictions for [[4.0], [7.0]]:[[21.85423469543457], [37.832366943359375]]
# Learned weight:2.4132,learned bias:0.1221
# Predictions for [[4.0], [7.0]]:[[9.774836540222168], [17.014413833618164]]
# Learned weight:-0.4446,learned bias:-0.2818
# Predictions for [[4.0], [7.0]]:[[-2.0600666999816895], [-3.393733263015747]]
# Learned weight:-1.1938,learned bias:-0.3588
# Predictions for [[4.0], [7.0]]:[[-5.134073257446289], [-8.715547561645508]]
# Learned weight:0.7008,learned bias:-0.0299
# Predictions for [[4.0], [7.0]]:[[2.7731869220733643], [4.875491142272949]]
# Learned weight:3.8716,learned bias:0.5028
# Predictions for [[4.0], [7.0]]:[[15.989179611206055], [27.603975296020508]]
# Learned weight:6.0316,learned bias:0.9015
# Predictions for [[4.0], [7.0]]:[[25.02791976928711], [43.12276077270508]]
# Learned weight:5.6191,learned bias:0.9353
# Predictions for [[4.0], [7.0]]:[[23.41191864013672], [40.269351959228516]]
# Learned weight:2.9211,learned bias:0.6463
# Predictions for [[4.0], [7.0]]:[[12.330504417419434], [21.093666076660156]]
# Learned weight:-0.1335,learned bias:0.3184
# Predictions for [[4.0], [7.0]]:[[-0.2156538963317871], [-0.6162198781967163]]
# Learned weight:-1.3605,learned bias:0.2735
# Predictions for [[4.0], [7.0]]:[[-5.168529033660889], [-9.25002670288086]]
# Learned weight:0.1085,learned bias:0.6389
# Predictions for [[4.0], [7.0]]:[[1.0728322267532349], [1.3983023166656494]]
# Learned weight:3.2017,learned bias:1.2558
# Predictions for [[4.0], [7.0]]:[[14.062410354614258], [23.667377471923828]]
# Learned weight:5.6779,learned bias:1.7928
# Predictions for [[4.0], [7.0]]:[[24.504472732543945], [41.53825759887695]]
# Learned weight:5.7387,learned bias:1.9836
# Predictions for [[4.0], [7.0]]:[[24.938560485839844], [42.154781341552734]]
# Learned weight:3.3216,learned bias:1.8182
# Predictions for [[4.0], [7.0]]:[[15.104593276977539], [25.069385528564453]]
# Learned weight:0.1451,learned bias:1.5492
# Predictions for [[4.0], [7.0]]:[[2.1296677589416504], [2.56498384475708]]
# Learned weight:-1.5269,learned bias:1.5098
# Predictions for [[4.0], [7.0]]:[[-4.597803115844727], [-9.17851734161377]]
# Learned weight:-0.5134,learned bias:1.8732
# Predictions for [[4.0], [7.0]]:[[-0.18023443222045898], [-1.7203068733215332]]
# Learned weight:2.4348,learned bias:2.5276
# Predictions for [[4.0], [7.0]]:[[12.26665210723877], [19.57097816467285]]
# Learned weight:5.1747,learned bias:3.1557
# Predictions for [[4.0], [7.0]]:[[23.85426902770996], [39.378231048583984]]
# Learned weight:5.7127,learned bias:3.4623
# Predictions for [[4.0], [7.0]]:[[26.313270568847656], [43.451515197753906]]
# Learned weight:3.6386,learned bias:3.3858
# Predictions for [[4.0], [7.0]]:[[17.9403133392334], [28.856218338012695]]
# Learned weight:0.4203,learned bias:3.1417
# Predictions for [[4.0], [7.0]]:[[4.822749614715576], [6.083573341369629]]
# Learned weight:-1.6516,learned bias:3.0668
# Predictions for [[4.0], [7.0]]:[[-3.539541482925415], [-8.494312286376953]]
# Learned weight:-1.1108,learned bias:3.3765
# Predictions for [[4.0], [7.0]]:[[-1.0664961338043213], [-4.398758888244629]]
# Learned weight:1.6301,learned bias:4.0088
# Predictions for [[4.0], [7.0]]:[[10.529210090637207], [15.419544219970703]]
# Learned weight:4.5764,learned bias:4.6681
# Predictions for [[4.0], [7.0]]:[[22.97355842590332], [36.70261764526367]]
# Learned weight:5.5859,learned bias:5.0375
# Predictions for [[4.0], [7.0]]:[[27.381303787231445], [44.1391487121582]]
# Learned weight:3.9101,learned bias:5.0053
# Predictions for [[4.0], [7.0]]:[[20.645673751831055], [32.37592315673828]]
# Learned weight:0.7318,learned bias:4.7452
# Predictions for [[4.0], [7.0]]:[[7.672362804412842], [9.86777114868164]]
# Learned weight:-1.6847,learned bias:4.5900
# Predictions for [[4.0], [7.0]]:[[-2.1487913131713867], [-7.202917098999023]]
# Learned weight:-1.6224,learned bias:4.7924
# Predictions for [[4.0], [7.0]]:[[-1.696983814239502], [-6.564036846160889]]
# Learned weight:0.8541,learned bias:5.3418
# Predictions for [[4.0], [7.0]]:[[8.758203506469727], [11.32050609588623]]
# Learned weight:3.9447,learned bias:5.9717
# Predictions for [[4.0], [7.0]]:[[21.75041961669922], [33.584449768066406]]
# Learned weight:5.4088,learned bias:6.3507
# Predictions for [[4.0], [7.0]]:[[27.985862731933594], [44.212223052978516]]
# Learned weight:4.1767,learned bias:6.3202
# Predictions for [[4.0], [7.0]]:[[23.026878356933594], [35.55690002441406]]
# Learned weight:1.1188,learned bias:6.0078
# Predictions for [[4.0], [7.0]]:[[10.483159065246582], [13.839652061462402]]
# Learned weight:-1.5800,learned bias:5.7354
# Predictions for [[4.0], [7.0]]:[[-0.5844378471374512], [-5.324307918548584]]
# Learned weight:-1.9918,learned bias:5.7867
# Predictions for [[4.0], [7.0]]:[[-2.180389881134033], [-8.155715942382812]]
# Learned weight:0.1680,learned bias:6.2033
# Predictions for [[4.0], [7.0]]:[[6.875178813934326], [7.379112720489502]]
# Learned weight:3.3360,learned bias:6.7539
# Predictions for [[4.0], [7.0]]:[[20.097810745239258], [30.10573959350586]]
# Learned weight:5.2253,learned bias:7.1008
# Predictions for [[4.0], [7.0]]:[[28.002017974853516], [43.67793655395508]]
# Learned weight:4.4702,learned bias:7.0421
# Predictions for [[4.0], [7.0]]:[[24.922836303710938], [38.33341598510742]]
# Learned weight:1.6083,learned bias:6.6568
# Predictions for [[4.0], [7.0]]:[[13.089824676513672], [17.91458511352539]]
# Learned weight:-1.3061,learned bias:6.2480
# Predictions for [[4.0], [7.0]]:[[1.0235438346862793], [-2.8947858810424805]]
# Learned weight:-2.1792,learned bias:6.1244
# Predictions for [[4.0], [7.0]]:[[-2.5922207832336426], [-9.129703521728516]]
# Learned weight:-0.3836,learned bias:6.3787
# Predictions for [[4.0], [7.0]]:[[4.84438943862915], [3.693678140640259]]
# Learned weight:2.7904,learned bias:6.8204
# Predictions for [[4.0], [7.0]]:[[17.982118606567383], [26.353410720825195]]
# Learned weight:5.0629,learned bias:7.1133
# Predictions for [[4.0], [7.0]]:[[27.36507797241211], [42.553897857666016]]
# Learned weight:4.8040,learned bias:7.0171
# Predictions for [[4.0], [7.0]]:[[26.233173370361328], [40.64520263671875]]
# Learned weight:2.2058,learned bias:6.5605
# Predictions for [[4.0], [7.0]]:[[15.383822441101074], [22.001331329345703]]
# Learned weight:-0.8555,learned bias:6.0205
# Predictions for [[4.0], [7.0]]:[[2.598564863204956], [0.03209495544433594]]
# Learned weight:-2.1693,learned bias:5.7239
# Predictions for [[4.0], [7.0]]:[[-2.9531030654907227], [-9.460855484008789]]
# Learned weight:-0.7800,learned bias:5.8121
# Predictions for [[4.0], [7.0]]:[[2.691965341567993], [0.3518862724304199]]
# Learned weight:2.3251,learned bias:6.1400
# Predictions for [[4.0], [7.0]]:[[15.440542221069336], [22.41598129272461]]
# Learned weight:4.9266,learned bias:6.3806
# Predictions for [[4.0], [7.0]]:[[26.08689308166504], [40.8665771484375]]
# Learned weight:5.1681,learned bias:6.2609
# Predictions for [[4.0], [7.0]]:[[26.933460235595703], [42.43784713745117]]
# Learned weight:2.8921,learned bias:5.7583
# Predictions for [[4.0], [7.0]]:[[17.326913833618164], [26.003347396850586]]
# Learned weight:-0.2474,learned bias:5.1177
# Predictions for [[4.0], [7.0]]:[[4.1282124519348145], [3.3861167430877686]]
# Learned weight:-1.9743,learned bias:4.6757
# Predictions for [[4.0], [7.0]]:[[-3.2213592529296875], [-9.144121170043945]]
# Learned weight:-1.0273,learned bias:4.6193
# Predictions for [[4.0], [7.0]]:[[0.5101571083068848], [-2.5716867446899414]]
# Learned weight:1.9327,learned bias:4.8520
# Predictions for [[4.0], [7.0]]:[[12.582980155944824], [18.381227493286133]]
# Learned weight:4.7981,learned bias:5.0637
# Predictions for [[4.0], [7.0]]:[[24.256227493286133], [38.650596618652344]]
# Learned weight:5.5299,learned bias:4.9547
# Predictions for [[4.0], [7.0]]:[[27.074378967285156], [43.66415023803711]]
# Learned weight:3.6242,learned bias:4.4515
# Predictions for [[4.0], [7.0]]:[[18.948522567749023], [29.82126808166504]]
# Learned weight:0.4745,learned bias:3.7609
# Predictions for [[4.0], [7.0]]:[[5.658938407897949], [7.082451343536377]]
# Learned weight:-1.6308,learned bias:3.2216
# Predictions for [[4.0], [7.0]]:[[-3.3016040325164795], [-8.194025039672852]]
# Learned weight:-1.1540,learned bias:3.0616
# Predictions for [[4.0], [7.0]]:[[-1.5544557571411133], [-5.016511917114258]]
# Learned weight:1.5857,learned bias:3.2349
# Predictions for [[4.0], [7.0]]:[[9.577886581420898], [14.335111618041992]]
# Learned weight:4.6419,learned bias:3.4554
# Predictions for [[4.0], [7.0]]:[[22.023197174072266], [35.949039459228516]]
# Learned weight:5.8404,learned bias:3.4034
# Predictions for [[4.0], [7.0]]:[[26.765146255493164], [44.28647232055664]]
# Learned weight:4.3429,learned bias:2.9562
# Predictions for [[4.0], [7.0]]:[[20.32788848876953], [33.35663604736328]]
# Learned weight:1.2497,learned bias:2.2774
# Predictions for [[4.0], [7.0]]:[[7.276108741760254], [11.02514934539795]]
# Learned weight:-1.1918,learned bias:1.6996
# Predictions for [[4.0], [7.0]]:[[-3.06746244430542], [-6.642730236053467]]
# Learned weight:-1.2031,learned bias:1.4862
# Predictions for [[4.0], [7.0]]:[[-3.3263726234436035], [-6.935781002044678]]
# Learned weight:1.2456,learned bias:1.6427
# Predictions for [[4.0], [7.0]]:[[6.624920845031738], [10.361612319946289]]
# Learned weight:4.4144,learned bias:1.9133
# Predictions for [[4.0], [7.0]]:[[19.571060180664062], [32.81439208984375]]
# Learned weight:6.0449,learned bias:1.9657
# Predictions for [[4.0], [7.0]]:[[26.145132064819336], [44.27970504760742]]
# Learned weight:4.9837,learned bias:1.6307
# Predictions for [[4.0], [7.0]]:[[21.565349578857422], [36.51636505126953]]
# Learned weight:2.0125,learned bias:1.0243
# Predictions for [[4.0], [7.0]]:[[9.074228286743164], [15.111644744873047]]
# Learned weight:-0.7146,learned bias:0.4654
# Predictions for [[4.0], [7.0]]:[[-2.393092393875122], [-4.536960124969482]]
# Learned weight:-1.2202,learned bias:0.2464
# Predictions for [[4.0], [7.0]]:[[-4.6345086097717285], [-8.295154571533203]]
# Learned weight:0.8742,learned bias:0.4237
# Predictions for [[4.0], [7.0]]:[[3.920560836791992], [6.543170928955078]]
# Learned weight:4.0760,learned bias:0.7780
# Predictions for [[4.0], [7.0]]:[[17.08184242248535], [29.309755325317383]]
# Learned weight:6.0947,learned bias:0.9716
# Predictions for [[4.0], [7.0]]:[[25.350257873535156], [43.63425827026367]]
# Learned weight:5.4893,learned bias:0.7925
# Predictions for [[4.0], [7.0]]:[[22.749547958374023], [39.217323303222656]]
# Learned weight:2.7044,learned bias:0.3068
# Predictions for [[4.0], [7.0]]:[[11.124348640441895], [19.23754119873047]]
# Learned weight:-0.2494,learned bias:-0.1887
# Predictions for [[4.0], [7.0]]:[[-1.1862801313400269], [-1.934502363204956]]
# Learned weight:-1.2417,learned bias:-0.3791
# Predictions for [[4.0], [7.0]]:[[-5.345961093902588], [-9.071125984191895]]
# Learned weight:0.4456,learned bias:-0.1583
# Predictions for [[4.0], [7.0]]:[[1.6242135763168335], [2.9611241817474365]]
# Learned weight:3.6021,learned bias:0.2951
# Predictions for [[4.0], [7.0]]:[[14.703412055969238], [25.509658813476562]]
# Learned weight:5.9589,learned bias:0.6465
# Predictions for [[4.0], [7.0]]:[[24.4819278717041], [42.358524322509766]]
# Learned weight:5.8207,learned bias:0.6456
# Predictions for [[4.0], [7.0]]:[[23.928382873535156], [41.39043426513672]]
# Learned weight:3.2849,learned bias:0.3069
# Predictions for [[4.0], [7.0]]:[[13.446473121643066], [23.30115509033203]]
# Learned weight:0.1715,learned bias:-0.1014
# Predictions for [[4.0], [7.0]]:[[0.5846295952796936], [1.0991477966308594]]
# Learned weight:-1.2857,learned bias:-0.2499
# Predictions for [[4.0], [7.0]]:[[-5.3926496505737305], [-9.249732971191406]]
# Learned weight:-0.0456,learned bias:0.0148
# Predictions for [[4.0], [7.0]]:[[-0.1676163226366043], [-0.30440598726272583]]
# Learned weight:2.9915,learned bias:0.5593
# Predictions for [[4.0], [7.0]]:[[12.525435447692871], [21.500036239624023]]
# Learned weight:5.6315,learned bias:1.0595
# Predictions for [[4.0], [7.0]]:[[23.58565330505371], [40.480262756347656]]
# Learned weight:5.9644,learned bias:1.2330
# Predictions for [[4.0], [7.0]]:[[25.090560913085938], [42.98372268676758]]
# Learned weight:3.7379,learned bias:1.0420
# Predictions for [[4.0], [7.0]]:[[15.993513107299805], [27.207130432128906]]
# Learned weight:0.5390,learned bias:0.7201
# Predictions for [[4.0], [7.0]]:[[2.8762447834014893], [4.493389129638672]]
# Learned weight:-1.3471,learned bias:0.6035
# Predictions for [[4.0], [7.0]]:[[-4.784708023071289], [-8.82590103149414]]
# Learned weight:-0.5807,learned bias:0.8894
# Predictions for [[4.0], [7.0]]:[[-1.4334577322006226], [-3.1756224632263184]]
# Learned weight:2.2691,learned bias:1.4929
# Predictions for [[4.0], [7.0]]:[[10.569384574890137], [17.376739501953125]]
# Learned weight:5.1341,learned bias:2.1079
# Predictions for [[4.0], [7.0]]:[[22.644153594970703], [38.046329498291016]]
# Learned weight:5.9339,learned bias:2.4266
# Predictions for [[4.0], [7.0]]:[[26.162120819091797], [43.96376419067383]]
# Learned weight:4.0727,learned bias:2.3600
# Predictions for [[4.0], [7.0]]:[[18.650753021240234], [30.86878776550293]]
# Learned weight:0.8675,learned bias:2.1016
# Predictions for [[4.0], [7.0]]:[[5.571622848510742], [8.174135208129883]]
# Learned weight:-1.3987,learned bias:1.9871
# Predictions for [[4.0], [7.0]]:[[-3.6076903343200684], [-7.8038010597229]]
# Learned weight:-1.1188,learned bias:2.2527
# Predictions for [[4.0], [7.0]]:[[-2.222687005996704], [-5.579211235046387]]
# Learned weight:1.4827,learned bias:2.8641
# Predictions for [[4.0], [7.0]]:[[8.794827461242676], [13.242881774902344]]
# Learned weight:4.5115,learned bias:3.5407
# Predictions for [[4.0], [7.0]]:[[21.58657455444336], [35.12095642089844]]
# Learned weight:5.7656,learned bias:3.9566
# Predictions for [[4.0], [7.0]]:[[27.018930435180664], [44.31566619873047]]
# Learned weight:4.3193,learned bias:3.9740
# Predictions for [[4.0], [7.0]]:[[21.251237869262695], [34.209136962890625]]
# Learned weight:1.1889,learned bias:3.7419
# Predictions for [[4.0], [7.0]]:[[8.497584342956543], [12.064380645751953]]
# Learned weight:-1.3980,learned bias:3.5877
# Predictions for [[4.0], [7.0]]:[[-2.0041611194610596], [-6.198025703430176]]
# Learned weight:-1.6044,learned bias:3.7814
# Predictions for [[4.0], [7.0]]:[[-2.636270523071289], [-7.449531078338623]]
# Learned weight:0.6949,learned bias:4.3405
# Predictions for [[4.0], [7.0]]:[[7.120087623596191], [9.204750061035156]]
# Learned weight:3.8237,learned bias:5.0166
# Predictions for [[4.0], [7.0]]:[[20.311418533325195], [31.782499313354492]]
# Learned weight:5.5097,learned bias:5.4734
# Predictions for [[4.0], [7.0]]:[[27.512346267700195], [44.041534423828125]]
# Learned weight:4.5190,learned bias:5.5278
# Predictions for [[4.0], [7.0]]:[[23.60376739501953], [37.160736083984375]]
# Learned weight:1.5433,learned bias:5.2809
# Predictions for [[4.0], [7.0]]:[[11.454084396362305], [16.083969116210938]]
# Learned weight:-1.2972,learned bias:5.0446
# Predictions for [[4.0], [7.0]]:[[-0.1439533233642578], [-4.035405158996582]]
# Learned weight:-1.9784,learned bias:5.1168
# Predictions for [[4.0], [7.0]]:[[-2.7969870567321777], [-8.732330322265625]]
# Learned weight:-0.0284,learned bias:5.5662
# Predictions for [[4.0], [7.0]]:[[5.452442646026611], [5.367115020751953]]
# Learned weight:3.1338,learned bias:6.1827
# Predictions for [[4.0], [7.0]]:[[18.717910766601562], [28.119308471679688]]
# Learned weight:5.2186,learned bias:6.6277
# Predictions for [[4.0], [7.0]]:[[27.502229690551758], [43.15809631347656]]
# Learned weight:4.7125,learned bias:6.6773
# Predictions for [[4.0], [7.0]]:[[25.52734375], [39.66487503051758]]
# Learned weight:1.9666,learned bias:6.3826
# Predictions for [[4.0], [7.0]]:[[14.249129295349121], [20.148998260498047]]
# Learned weight:-1.0557,learned bias:6.0329
# Predictions for [[4.0], [7.0]]:[[1.8102035522460938], [-1.3568248748779297]]
# Learned weight:-2.1908,learned bias:5.9469
# Predictions for [[4.0], [7.0]]:[[-2.8161544799804688], [-9.38845443725586]]
# Learned weight:-0.6307,learned bias:6.2435
# Predictions for [[4.0], [7.0]]:[[3.72054123878479], [1.8283424377441406]]
# Learned weight:2.4956,learned bias:6.7557
# Predictions for [[4.0], [7.0]]:[[16.738309860229492], [24.225255966186523]]
# Learned weight:4.9347,learned bias:7.1509
# Predictions for [[4.0], [7.0]]:[[26.88974952697754], [41.69391632080078]]
# Learned weight:4.9287,learned bias:7.1694
# Predictions for [[4.0], [7.0]]:[[26.884342193603516], [41.670570373535156]]
# Learned weight:2.4800,learned bias:6.8115
# Predictions for [[4.0], [7.0]]:[[16.731531143188477], [24.17155647277832]]
# Learned weight:-0.6508,learned bias:6.3370
# Predictions for [[4.0], [7.0]]:[[3.733907461166382], [1.781571388244629]]
# Learned weight:-2.2108,learned bias:6.0784
# Predictions for [[4.0], [7.0]]:[[-2.764608860015869], [-9.39688491821289]]
# Learned weight:-1.0751,learned bias:6.2018
# Predictions for [[4.0], [7.0]]:[[1.901388168334961], [-1.3239350318908691]]
# Learned weight:1.9440,learned bias:6.5876
# Predictions for [[4.0], [7.0]]:[[14.363592147827148], [20.195608139038086]]
# Learned weight:4.6815,learned bias:6.9165
# Predictions for [[4.0], [7.0]]:[[25.642438888549805], [39.68689727783203]]
# Learned weight:5.1764,learned bias:6.8996
# Predictions for [[4.0], [7.0]]:[[27.605026245117188], [43.13409423828125]]
# Learned weight:3.0820,learned bias:6.4862
# Predictions for [[4.0], [7.0]]:[[18.814159393310547], [28.060144424438477]]
# Learned weight:-0.0846,learned bias:5.9006
# Predictions for [[4.0], [7.0]]:[[5.562060356140137], [5.308192253112793]]
# Learned weight:-2.0339,learned bias:5.4811
# Predictions for [[4.0], [7.0]]:[[-2.654667377471924], [-8.756511688232422]]
# Learned weight:-1.3505,learned bias:5.4374
# Predictions for [[4.0], [7.0]]:[[0.035440921783447266], [-4.016022682189941]]
# Learned weight:1.4891,learned bias:5.6997
# Predictions for [[4.0], [7.0]]:[[11.656315803527832], [16.123764038085938]]
# Learned weight:4.4589,learned bias:5.9699
# Predictions for [[4.0], [7.0]]:[[23.805679321289062], [37.18251419067383]]
# Learned weight:5.4404,learned bias:5.9362
# Predictions for [[4.0], [7.0]]:[[27.69792938232422], [44.019264221191406]]
# Learned weight:3.7462,learned bias:5.4979
# Predictions for [[4.0], [7.0]]:[[20.48271369934082], [31.721328735351562]]
# Learned weight:0.6141,learned bias:4.8387
# Predictions for [[4.0], [7.0]]:[[7.2950592041015625], [9.137343406677246]]
# Learned weight:-1.6830,learned bias:4.2948
# Predictions for [[4.0], [7.0]]:[[-2.437318801879883], [-7.486423015594482]]
# Learned weight:-1.4720,learned bias:4.1142
# Predictions for [[4.0], [7.0]]:[[-1.7738895416259766], [-6.189939022064209]]
# Learned weight:1.1172,learned bias:4.2786
# Predictions for [[4.0], [7.0]]:[[8.747552871704102], [12.099272727966309]]
# Learned weight:4.2451,learned bias:4.5177
# Predictions for [[4.0], [7.0]]:[[21.497940063476562], [34.233154296875]]
# Learned weight:5.6850,learned bias:4.5039
# Predictions for [[4.0], [7.0]]:[[27.24383544921875], [44.298789978027344]]
# Learned weight:4.4248,learned bias:4.0891
# Predictions for [[4.0], [7.0]]:[[21.78814697265625], [35.062469482421875]]
# Learned weight:1.3944,learned bias:3.4114
# Predictions for [[4.0], [7.0]]:[[8.988862991333008], [13.171945571899414]]
# Learned weight:-1.2031,learned bias:2.7972
# Predictions for [[4.0], [7.0]]:[[-2.015186309814453], [-5.6244659423828125]]
# Learned weight:-1.4757,learned bias:2.5266
# Predictions for [[4.0], [7.0]]:[[-3.376386880874634], [-7.803635597229004]]
# Learned weight:0.7962,learned bias:2.6332
# Predictions for [[4.0], [7.0]]:[[5.818202018737793], [8.206931114196777]]
# Learned weight:4.0025,learned bias:2.8805
# Predictions for [[4.0], [7.0]]:[[18.890602111816406], [30.898162841796875]]
# Learned weight:5.8605,learned bias:2.9328
# Predictions for [[4.0], [7.0]]:[[26.374835968017578], [43.956390380859375]]
# Learned weight:5.0569,learned bias:2.5972
# Predictions for [[4.0], [7.0]]:[[22.824880599975586], [37.995628356933594]]
# Learned weight:2.1920,learned bias:1.9635
# Predictions for [[4.0], [7.0]]:[[10.731597900390625], [17.307662963867188]]
# Learned weight:-0.6521,learned bias:1.3399
# Predictions for [[4.0], [7.0]]:[[-1.2683278322219849], [-3.2244787216186523]]
# Learned weight:-1.4089,learned bias:1.0322
# Predictions for [[4.0], [7.0]]:[[-4.60334587097168], [-8.829996109008789]]
# Learned weight:0.4860,learned bias:1.1247
# Predictions for [[4.0], [7.0]]:[[3.0688302516937256], [4.52693510055542]]
# Learned weight:3.6892,learned bias:1.4200
# Predictions for [[4.0], [7.0]]:[[16.176990509033203], [27.244705200195312]]
# Learned weight:5.9154,learned bias:1.5819
# Predictions for [[4.0], [7.0]]:[[25.24334144592285], [42.98944854736328]]
# Learned weight:5.5807,learned bias:1.3773
# Predictions for [[4.0], [7.0]]:[[23.699880599975586], [40.44184112548828]]
# Learned weight:2.9418,learned bias:0.8449
# Predictions for [[4.0], [7.0]]:[[12.612150192260742], [21.437610626220703]]
# Learned weight:-0.0886,learned bias:0.2676
# Predictions for [[4.0], [7.0]]:[[-0.08685830235481262], [-0.35267317295074463]]
# Learned weight:-1.3178,learned bias:-0.0305
# Predictions for [[4.0], [7.0]]:[[-5.3016839027404785], [-9.255091667175293]]
# Learned weight:0.1503,learned bias:0.0835
# Predictions for [[4.0], [7.0]]:[[0.6846014261245728], [1.1354029178619385]]
# Learned weight:3.2704,learned bias:0.4558
# Predictions for [[4.0], [7.0]]:[[13.537436485290527], [23.348628997802734]]
# Learned weight:5.8078,learned bias:0.7571
# Predictions for [[4.0], [7.0]]:[[23.98820686340332], [41.4115104675293]]
# Learned weight:5.9451,learned bias:0.7196
# Predictions for [[4.0], [7.0]]:[[24.500080108642578], [42.335445404052734]]
# Learned weight:3.5896,learned bias:0.3298
# Predictions for [[4.0], [7.0]]:[[14.688369750976562], [25.457290649414062]]
# Learned weight:0.4397,learned bias:-0.1614
# Predictions for [[4.0], [7.0]]:[[1.5972713232040405], [2.9162890911102295]]
# Learned weight:-1.2367,learned bias:-0.4193
# Predictions for [[4.0], [7.0]]:[[-5.366057872772217], [-9.076128959655762]]
# Learned weight:-0.2328,learned bias:-0.2657
# Predictions for [[4.0], [7.0]]:[[-1.1968157291412354], [-1.8951349258422852]]
# Learned weight:2.7289,learned bias:0.1927
# Predictions for [[4.0], [7.0]]:[[11.108161926269531], [19.29478645324707]]
# Learned weight:5.5161,learned bias:0.6411
# Predictions for [[4.0], [7.0]]:[[22.705625534057617], [39.25398635864258]]
# Learned weight:6.1206,learned bias:0.7832
# Predictions for [[4.0], [7.0]]:[[25.26568603515625], [43.627540588378906]]
# Learned weight:4.1022,learned bias:0.5537
# Predictions for [[4.0], [7.0]]:[[16.962371826171875], [29.268909454345703]]
# Learned weight:0.9054,learned bias:0.1653
# Predictions for [[4.0], [7.0]]:[[3.786738395690918], [6.502815246582031]]
# Learned weight:-1.1794,learned bias:-0.0443
# Predictions for [[4.0], [7.0]]:[[-4.761805534362793], [-8.29995059967041]]
# Learned weight:-0.6629,learned bias:0.1442
# Predictions for [[4.0], [7.0]]:[[-2.507312059402466], [-4.495932102203369]]
# Learned weight:2.0718,learned bias:0.6736
# Predictions for [[4.0], [7.0]]:[[8.961010932922363], [15.176551818847656]]
# Learned weight:5.0451,learned bias:1.2513
# Predictions for [[4.0], [7.0]]:[[21.431564331054688], [36.566741943359375]]
# Learned weight:6.1042,learned bias:1.5590
# Predictions for [[4.0], [7.0]]:[[25.975717544555664], [44.288246154785156]]
# Learned weight:4.4719,learned bias:1.4813
# Predictions for [[4.0], [7.0]]:[[19.368825912475586], [32.78450393676758]]
# Learned weight:1.3053,learned bias:1.1880
# Predictions for [[4.0], [7.0]]:[[6.409099102020264], [10.324919700622559]]
# Learned weight:-1.1363,learned bias:1.0118
# Predictions for [[4.0], [7.0]]:[[-3.533357858657837], [-6.942237854003906]]
# Learned weight:-1.1159,learned bias:1.2081
# Predictions for [[4.0], [7.0]]:[[-3.2554843425750732], [-6.603171348571777]]
# Learned weight:1.3319,learned bias:1.7708
# Predictions for [[4.0], [7.0]]:[[7.098254203796387], [11.093828201293945]]
# Learned weight:4.4258,learned bias:2.4362
# Predictions for [[4.0], [7.0]]:[[20.139501571655273], [33.416969299316406]]
# Learned weight:5.9194,learned bias:2.8718
# Predictions for [[4.0], [7.0]]:[[26.549211502075195], [44.30729675292969]]
# Learned weight:4.7162,learned bias:2.9147
# Predictions for [[4.0], [7.0]]:[[21.779361724853516], [35.92787170410156]]
# Learned weight:1.6588,learned bias:2.6882
# Predictions for [[4.0], [7.0]]:[[9.323451042175293], [14.299861907958984]]
# Learned weight:-1.0772,learned bias:2.5124
# Predictions for [[4.0], [7.0]]:[[-1.7962243556976318], [-5.027677536010742]]
# Learned weight:-1.5476,learned bias:2.6729
# Predictions for [[4.0], [7.0]]:[[-3.5174453258514404], [-8.160189628601074]]
# Learned weight:0.5621,learned bias:3.2151
# Predictions for [[4.0], [7.0]]:[[5.463518142700195], [7.149858474731445]]
# Learned weight:3.7109,learned bias:3.9104
# Predictions for [[4.0], [7.0]]:[[18.75396728515625], [29.886615753173828]]
# Learned weight:5.6104,learned bias:4.4202
# Predictions for [[4.0], [7.0]]:[[26.861919403076172], [43.693172454833984]]
# Learned weight:4.8710,learned bias:4.5383
# Predictions for [[4.0], [7.0]]:[[24.022130966186523], [38.634986877441406]]
# Learned weight:2.0008,learned bias:4.3386
# Predictions for [[4.0], [7.0]]:[[12.341991424560547], [18.344533920288086]]
# Learned weight:-0.9589,learned bias:4.1212
# Predictions for [[4.0], [7.0]]:[[0.28562068939208984], [-2.5910396575927734]]
# Learned weight:-1.9023,learned bias:4.1957
# Predictions for [[4.0], [7.0]]:[[-3.413567066192627], [-9.12053108215332]]
# Learned weight:-0.1730,learned bias:4.6581
# Predictions for [[4.0], [7.0]]:[[3.966014862060547], [3.446958541870117]]
# Learned weight:2.9640,learned bias:5.3206
# Predictions for [[4.0], [7.0]]:[[17.176559448242188], [26.06850814819336]]
# Learned weight:5.2320,learned bias:5.8465
# Predictions for [[4.0], [7.0]]:[[26.77463722229004], [42.47077560424805]]
# Learned weight:4.9803,learned bias:5.9911
# Predictions for [[4.0], [7.0]]:[[25.912363052368164], [40.85333251953125]]
# Learned weight:2.3711,learned bias:5.7775
# Predictions for [[4.0], [7.0]]:[[15.261934280395508], [22.375232696533203]]
# Learned weight:-0.7368,learned bias:5.4793
# Predictions for [[4.0], [7.0]]:[[2.5319528579711914], [0.3214259147644043]]
# Learned weight:-2.1249,learned bias:5.4230
# Predictions for [[4.0], [7.0]]:[[-3.076608657836914], [-9.45132827758789]]
# Learned weight:-0.8102,learned bias:5.7530
# Predictions for [[4.0], [7.0]]:[[2.5123138427734375], [0.08183526992797852]]
# Learned weight:2.2478,learned bias:6.3269
# Predictions for [[4.0], [7.0]]:[[15.318275451660156], [22.061813354492188]]
# Learned weight:4.8372,learned bias:6.8179
# Predictions for [[4.0], [7.0]]:[[26.166767120361328], [40.678443908691406]]
# Learned weight:5.0845,learned bias:6.9489
# Predictions for [[4.0], [7.0]]:[[27.287080764770508], [42.540687561035156]]
# Learned weight:2.8022,learned bias:6.6920
# Predictions for [[4.0], [7.0]]:[[17.900611877441406], [26.307104110717773]]
# Learned weight:-0.3767,learned bias:6.2875
# Predictions for [[4.0], [7.0]]:[[4.780693054199219], [3.6505680084228516]]
# Learned weight:-2.1726,learned bias:6.0717
# Predictions for [[4.0], [7.0]]:[[-2.6187009811401367], [-9.136496543884277]]
# Learned weight:-1.2990,learned bias:6.2340
# Predictions for [[4.0], [7.0]]:[[1.0379376411437988], [-2.859142303466797]]
# Learned weight:1.6123,learned bias:6.6812
# Predictions for [[4.0], [7.0]]:[[13.130446434020996], [17.96737289428711]]
# Learned weight:4.4658,learned bias:7.1039
# Predictions for [[4.0], [7.0]]:[[24.96729278564453], [38.364837646484375]]
# Learned weight:5.2092,learned bias:7.1993
# Predictions for [[4.0], [7.0]]:[[28.036231994628906], [43.66395568847656]]
# Learned weight:3.3093,learned bias:6.8887
# Predictions for [[4.0], [7.0]]:[[20.126070022583008], [30.05408477783203]]
# Learned weight:0.1356,learned bias:6.3745
# Predictions for [[4.0], [7.0]]:[[6.91690731048584], [7.3237409591674805]]
# Learned weight:-2.0247,learned bias:5.9942
# Predictions for [[4.0], [7.0]]:[[-2.104783058166504], [-8.179025650024414]]
# Learned weight:-1.6117,learned bias:5.9784
# Predictions for [[4.0], [7.0]]:[[-0.46848344802856445], [-5.3036723136901855]]
# Learned weight:1.0855,learned bias:6.2849
# Predictions for [[4.0], [7.0]]:[[10.627049446105957], [13.883698463439941]]
# Learned weight:4.1367,learned bias:6.6291
# Predictions for [[4.0], [7.0]]:[[23.175996780395508], [35.58620071411133]]
# Learned weight:5.3584,learned bias:6.6894
# Predictions for [[4.0], [7.0]]:[[28.123153686523438], [44.19847106933594]]
# Learned weight:3.8844,learned bias:6.3386
# Predictions for [[4.0], [7.0]]:[[21.876310348510742], [33.529579162597656]]
# Learned weight:0.7885,learned bias:5.7358
# Predictions for [[4.0], [7.0]]:[[8.889824867248535], [11.255334854125977]]
# Learned weight:-1.6878,learned bias:5.2124
# Predictions for [[4.0], [7.0]]:[[-1.5386319160461426], [-6.601921558380127]]
# Learned weight:-1.7472,learned bias:5.0344
# Predictions for [[4.0], [7.0]]:[[-1.9544930458068848], [-7.196149826049805]]
# Learned weight:0.6704,learned bias:5.2114
# Predictions for [[4.0], [7.0]]:[[7.892819881439209], [9.903890609741211]]
# Learned weight:3.8449,learned bias:5.4905
# Predictions for [[4.0], [7.0]]:[[20.869922637939453], [32.40449523925781]]
# Learned weight:5.5128,learned bias:5.5386
# Predictions for [[4.0], [7.0]]:[[27.589832305908203], [44.12824249267578]]
# Learned weight:4.4951,learned bias:5.1827
# Predictions for [[4.0], [7.0]]:[[23.163055419921875], [36.648319244384766]]
# Learned weight:1.5448,learned bias:4.5349
# Predictions for [[4.0], [7.0]]:[[10.714258193969727], [15.348787307739258]]
# Learned weight:-1.1943,learned bias:3.9125
# Predictions for [[4.0], [7.0]]:[[-0.8646368980407715], [-4.447469234466553]]
# Learned weight:-1.7299,learned bias:3.6105
# Predictions for [[4.0], [7.0]]:[[-3.3089606761932373], [-8.498557090759277]]
# Learned weight:0.3463,learned bias:3.6903
# Predictions for [[4.0], [7.0]]:[[5.075297832489014], [6.114072799682617]]
# Learned weight:3.5644,learned bias:3.9360
# Predictions for [[4.0], [7.0]]:[[18.193513870239258], [28.88666343688965]]
# Learned weight:5.6338,learned bias:4.0107
# Predictions for [[4.0], [7.0]]:[[26.545806884765625], [43.44710922241211]]
# Learned weight:5.0900,learned bias:3.6995
# Predictions for [[4.0], [7.0]]:[[24.05938720703125], [39.32926559448242]]
# Learned weight:2.3479,learned bias:3.0647
# Predictions for [[4.0], [7.0]]:[[12.456247329711914], [19.499881744384766]]
# Learned weight:-0.5967,learned bias:2.4019
# Predictions for [[4.0], [7.0]]:[[0.015065908432006836], [-1.7750489711761475]]
# Learned weight:-1.6026,learned bias:2.0280
# Predictions for [[4.0], [7.0]]:[[-4.382254600524902], [-9.189976692199707]]
# Learned weight:0.0769,learned bias:2.0545
# Predictions for [[4.0], [7.0]]:[[2.36212420463562], [2.592879295349121]]
# Learned weight:3.2568,learned bias:2.3073
# Predictions for [[4.0], [7.0]]:[[15.33441162109375], [25.104732513427734]]
# Learned weight:5.6725,learned bias:2.4535
# Predictions for [[4.0], [7.0]]:[[25.14333724975586], [42.16069412231445]]
# Learned weight:5.6084,learned bias:2.2409
# Predictions for [[4.0], [7.0]]:[[24.674379348754883], [41.49945068359375]]
# Learned weight:3.1315,learned bias:1.6804
# Predictions for [[4.0], [7.0]]:[[14.206600189208984], [23.601224899291992]]
# Learned weight:0.0434,learned bias:1.0387
# Predictions for [[4.0], [7.0]]:[[1.2122375965118408], [1.3423701524734497]]
# Learned weight:-1.4160,learned bias:0.6473
# Predictions for [[4.0], [7.0]]:[[-5.016847133636475], [-9.264921188354492]]
# Learned weight:-0.1789,learned bias:0.6644
# Predictions for [[4.0], [7.0]]:[[-0.05134463310241699], [-0.5881518721580505]]
# Learned weight:2.8820,learned bias:0.9622
# Predictions for [[4.0], [7.0]]:[[12.490317344665527], [21.13640594482422]]
# Learned weight:5.5814,learned bias:1.2189
# Predictions for [[4.0], [7.0]]:[[23.544462203979492], [40.28862762451172]]
# Learned weight:5.9925,learned bias:1.1509
# Predictions for [[4.0], [7.0]]:[[25.120712280273438], [43.098060607910156]]
# Learned weight:3.8329,learned bias:0.7172
# Predictions for [[4.0], [7.0]]:[[16.048612594604492], [27.54720115661621]]
# Learned weight:0.6676,learned bias:0.1491
# Predictions for [[4.0], [7.0]]:[[2.8195738792419434], [4.8224101066589355]]
# Learned weight:-1.2165,learned bias:-0.2153
# Predictions for [[4.0], [7.0]]:[[-5.08140230178833], [-8.73099136352539]]
# Learned weight:-0.4556,learned bias:-0.1744
# Predictions for [[4.0], [7.0]]:[[-1.9969220161437988], [-3.363811492919922]]
# Learned weight:2.4105,learned bias:0.1925
# Predictions for [[4.0], [7.0]]:[[9.834294319152832], [17.065675735473633]]
# Learned weight:5.3263,learned bias:0.5823
# Predictions for [[4.0], [7.0]]:[[21.88752555847168], [37.86647033691406]]
# Learned weight:6.1991,learned bias:0.6864
# Predictions for [[4.0], [7.0]]:[[25.48286247253418], [44.080196380615234]]
# Learned weight:4.4037,learned bias:0.4128
# Predictions for [[4.0], [7.0]]:[[18.027585983276367], [31.23868751525879]]
# Learned weight:1.2322,learned bias:-0.0479
# Predictions for [[4.0], [7.0]]:[[4.880812644958496], [8.577372550964355]]
# Learned weight:-1.0353,learned bias:-0.3593
# Predictions for [[4.0], [7.0]]:[[-4.500607013702393], [-7.606562614440918]]
# Learned weight:-0.7705,learned bias:-0.2813
# Predictions for [[4.0], [7.0]]:[[-3.363191604614258], [-5.674644470214844]]
# Learned weight:1.8322,learned bias:0.1574
# Predictions for [[4.0], [7.0]]:[[7.486238956451416], [12.982854843139648]]
# Learned weight:4.8953,learned bias:0.6794
# Predictions for [[4.0], [7.0]]:[[20.260746002197266], [34.946754455566406]]
# Learned weight:6.2088,learned bias:0.9582
# Predictions for [[4.0], [7.0]]:[[25.793338775634766], [44.419654846191406]]
# Learned weight:4.8192,learned bias:0.8529
# Predictions for [[4.0], [7.0]]:[[20.129505157470703], [34.586978912353516]]
# Learned weight:1.7156,learned bias:0.5088
# Predictions for [[4.0], [7.0]]:[[7.371065616607666], [12.51779842376709]]
# Learned weight:-0.8817,learned bias:0.2530
# Predictions for [[4.0], [7.0]]:[[-3.273876667022705], [-5.918997764587402]]
# Learned weight:-1.1180,learned bias:0.3585
# Predictions for [[4.0], [7.0]]:[[-4.113284111022949], [-7.4671454429626465]]
# Learned weight:1.1623,learned bias:0.8478
# Predictions for [[4.0], [7.0]]:[[5.4967570304870605], [8.98350715637207]]
# Learned weight:4.3033,learned bias:1.4756
# Predictions for [[4.0], [7.0]]:[[18.68876075744629], [31.598628997802734]]
# Learned weight:6.0293,learned bias:1.9055
# Predictions for [[4.0], [7.0]]:[[26.02252197265625], [44.110313415527344]]
# Learned weight:5.0808,learned bias:1.9507
# Predictions for [[4.0], [7.0]]:[[22.27400779724121], [37.51649856567383]]
# Learned weight:2.1210,learned bias:1.7082
# Predictions for [[4.0], [7.0]]:[[10.192090034484863], [16.55500602722168]]
# Learned weight:-0.7417,learned bias:1.4882
# Predictions for [[4.0], [7.0]]:[[-1.478615641593933], [-3.7037477493286133]]
# Learned weight:-1.4693,learned bias:1.5905
# Predictions for [[4.0], [7.0]]:[[-4.286886215209961], [-8.694916725158691]]
# Learned weight:0.4397,learned bias:2.0880
# Predictions for [[4.0], [7.0]]:[[3.8469605445861816], [5.166177749633789]]
# Learned weight:3.5903,learned bias:2.7739
# Predictions for [[4.0], [7.0]]:[[17.1351375579834], [27.906085968017578]]
# Learned weight:5.6938,learned bias:3.3094
# Predictions for [[4.0], [7.0]]:[[26.084495544433594], [43.16585159301758]]
# Learned weight:5.2142,learned bias:3.4667
# Predictions for [[4.0], [7.0]]:[[24.32341766357422], [39.9659423828125]]
# Learned weight:2.4729,learned bias:3.2923
# Predictions for [[4.0], [7.0]]:[[13.183773040771484], [20.602373123168945]]
# Learned weight:-0.5824,learned bias:3.0724
# Predictions for [[4.0], [7.0]]:[[0.7427902221679688], [-1.0044291019439697]]
# Learned weight:-1.7782,learned bias:3.1266
# Predictions for [[4.0], [7.0]]:[[-3.9861834049224854], [-9.320801734924316]]
# Learned weight:-0.2783,learned bias:3.5773
# Predictions for [[4.0], [7.0]]:[[2.463881731033325], [1.6288444995880127]]
# Learned weight:2.8149,learned bias:4.2605
# Predictions for [[4.0], [7.0]]:[[15.519986152648926], [23.964570999145508]]
# Learned weight:5.2535,learned bias:4.8437
# Predictions for [[4.0], [7.0]]:[[25.857563018798828], [41.61797332763672]]
# Learned weight:5.2607,learned bias:5.0635
# Predictions for [[4.0], [7.0]]:[[26.106117248535156], [41.88811111450195]]
# Learned weight:2.8087,learned bias:4.9147
# Predictions for [[4.0], [7.0]]:[[16.149559020996094], [24.575679779052734]]
# Learned weight:-0.3610,learned bias:4.6534
# Predictions for [[4.0], [7.0]]:[[3.2093923091888428], [2.126370429992676]]
# Learned weight:-1.9902,learned bias:4.6118
# Predictions for [[4.0], [7.0]]:[[-3.349061965942383], [-9.319684982299805]]
# Learned weight:-0.9277,learned bias:4.9587
# Predictions for [[4.0], [7.0]]:[[1.2477843761444092], [-1.5353894233703613]]
# Learned weight:2.0427,learned bias:5.5776
# Predictions for [[4.0], [7.0]]:[[13.748491287231445], [19.876649856567383]]
# Learned weight:4.7662,learned bias:6.1497
# Predictions for [[4.0], [7.0]]:[[25.214670181274414], [39.513370513916016]]
# Learned weight:5.2666,learned bias:6.3826
# Predictions for [[4.0], [7.0]]:[[27.448965072631836], [43.24871826171875]]
# Learned weight:3.1675,learned bias:6.2200
# Predictions for [[4.0], [7.0]]:[[18.890106201171875], [28.392671585083008]]
# Learned weight:-0.0365,learned bias:5.8817
# Predictions for [[4.0], [7.0]]:[[5.7355265617370605], [5.625887870788574]]
# Learned weight:-2.0552,learned bias:5.7050
# Predictions for [[4.0], [7.0]]:[[-2.515867233276367], [-8.681532859802246]]
# Learned weight:-1.4492,learned bias:5.9017
# Predictions for [[4.0], [7.0]]:[[0.10480213165283203], [-4.2428998947143555]]
# Learned weight:1.3345,learned bias:6.4054
# Predictions for [[4.0], [7.0]]:[[11.743568420410156], [15.747183799743652]]
# Learned weight:4.2845,learned bias:6.9188
# Predictions for [[4.0], [7.0]]:[[24.056798934936523], [36.910308837890625]]
# Learned weight:5.2711,learned bias:7.1272
# Predictions for [[4.0], [7.0]]:[[28.211551666259766], [44.024784088134766]]
# Learned weight:3.5783,learned bias:6.9248
# Predictions for [[4.0], [7.0]]:[[21.237873077392578], [31.972640991210938]]
# Learned weight:0.4186,learned bias:6.4903
# Predictions for [[4.0], [7.0]]:[[8.164599418640137], [9.420340538024902]]
# ...
# Predictions for [[4.0], [7.0]]:[[23.112409591674805], [35.19230270385742]]
# Learned weight:0.9788,learned bias:6.5152
# Predictions for [[4.0], [7.0]]:[[10.43033218383789], [13.366682052612305]]
# Learned weight:-1.6638,learned bias:6.0687
# Predictions for [[4.0], [7.0]]:[[-0.5863475799560547], [-5.577644348144531]]
# Learned weight:-1.9947,learned bias:5.9480
# Predictions for [[4.0], [7.0]]:[[-2.030966281890869], [-8.015174865722656]]
# Learned weight:0.2313,learned bias:6.1896
# Predictions for [[4.0], [7.0]]:[[7.114802360534668], [7.808738708496094]]
# Learned weight:3.4224,learned bias:6.5590
# Predictions for [[4.0], [7.0]]:[[20.248699188232422], [30.516008377075195]]
# Learned weight:5.2941,learned bias:6.7196
# Predictions for [[4.0], [7.0]]:[[27.89614486694336], [43.778568267822266]]
# Learned weight:4.5123,learned bias:6.4751
# Predictions for [[4.0], [7.0]]:[[24.524213790893555], [38.06103515625]]
# Learned weight:1.6524,learned bias:5.9111
# Predictions for [[4.0], [7.0]]:[[12.520917892456055], [17.478261947631836]]
# Learned weight:-1.2140,learned bias:5.3339
# Predictions for [[4.0], [7.0]]:[[0.4779801368713379], [-3.1639695167541504]]
# Learned weight:-2.0097,learned bias:5.0507
# Predictions for [[4.0], [7.0]]:[[-2.9878687858581543], [-9.016830444335938]]
# Learned weight:-0.1452,learned bias:5.1494
# Predictions for [[4.0], [7.0]]:[[4.56841516494751], [4.132698059082031]]
# Learned weight:3.0566,learned bias:5.4355
# Predictions for [[4.0], [7.0]]:[[17.66201400756836], [26.83191680908203]]
# Learned weight:5.3125,learned bias:5.5730
# Predictions for [[4.0], [7.0]]:[[26.823007583618164], [42.76050567626953]]
# Learned weight:5.0202,learned bias:5.3265
# Predictions for [[4.0], [7.0]]:[[25.40711784362793], [40.46758270263672]]
# Learned weight:2.4108,learned bias:4.7310
# Predictions for [[4.0], [7.0]]:[[14.374340057373047], [21.606826782226562]]
# Learned weight:-0.6172,learned bias:4.0677
# Predictions for [[4.0], [7.0]]:[[1.598827838897705], [-0.2528257369995117]]
# Learned weight:-1.8640,learned bias:3.6622
# Predictions for [[4.0], [7.0]]:[[-3.79368257522583], [-9.385576248168945]]
# Learned weight:-0.4099,learned bias:3.6512
# Predictions for [[4.0], [7.0]]:[[2.0114645957946777], [0.7816710472106934]]
# Learned weight:2.7225,learned bias:3.8849
# Predictions for [[4.0], [7.0]]:[[14.774761199951172], [22.942121505737305]]
# Learned weight:5.3040,learned bias:4.0356
# Predictions for [[4.0], [7.0]]:[[25.25177001953125], [41.16387939453125]]
# Learned weight:5.5020,learned bias:3.8339
# Predictions for [[4.0], [7.0]]:[[25.841772079467773], [42.347694396972656]]
# Learned weight:3.1977,learned bias:3.2633
# Predictions for [[4.0], [7.0]]:[[16.054285049438477], [25.647510528564453]]
# Learned weight:0.0723,learned bias:2.5731
# Predictions for [[4.0], [7.0]]:[[2.8621230125427246], [3.0789101123809814]]
# Learned weight:-1.6031,learned bias:2.0994
# Predictions for [[4.0], [7.0]]:[[-4.312931060791016], [-9.122175216674805]]
# Learned weight:-0.6001,learned bias:2.0246
# Predictions for [[4.0], [7.0]]:[[-0.37567830085754395], [-2.17587947845459]]
# Learned weight:2.3830,learned bias:2.2467
# Predictions for [[4.0], [7.0]]:[[11.778491973876953], [18.927350997924805]]
# Learned weight:5.2232,learned bias:2.4535
# Predictions for [[4.0], [7.0]]:[[23.34618377685547], [39.015708923339844]]
# Learned weight:5.8999,learned bias:2.3478
# Predictions for [[4.0], [7.0]]:[[25.94743537902832], [43.64712905883789]]
# Learned weight:3.9476,learned bias:1.8621
# Predictions for [[4.0], [7.0]]:[[17.652626037597656], [29.495553970336914]]
# Learned weight:0.7908,learned bias:1.2072
# Predictions for [[4.0], [7.0]]:[[4.370486736297607], [6.742916584014893]]
# Learned weight:-1.2808,learned bias:0.7222
# Predictions for [[4.0], [7.0]]:[[-4.401012897491455], [-8.243414878845215]]
# Learned weight:-0.7588,learned bias:0.6303
# Predictions for [[4.0], [7.0]]:[[-2.4050629138946533], [-4.681589126586914]]
# Learned weight:1.9987,learned bias:0.8796
# Predictions for [[4.0], [7.0]]:[[8.874517440795898], [14.870718002319336]]
# Learned weight:5.0250,learned bias:1.1805
# Predictions for [[4.0], [7.0]]:[[21.280630111694336], [36.35569381713867]]
# Learned weight:6.1586,learned bias:1.2150
# Predictions for [[4.0], [7.0]]:[[25.849458694458008], [44.325321197509766]]
# Learned weight:4.5980,learned bias:0.8652
# Predictions for [[4.0], [7.0]]:[[19.257173538208008], [33.05113983154297]]
# Learned weight:1.4778,learned bias:0.2993
# Predictions for [[4.0], [7.0]]:[[6.210521697998047], [10.643946647644043]]
# Learned weight:-0.9471,learned bias:-0.1496
# Predictions for [[4.0], [7.0]]:[[-3.937967300415039], [-6.77923583984375]]
# Learned weight:-0.9234,learned bias:-0.2223
# Predictions for [[4.0], [7.0]]:[[-3.915898084640503], [-6.686077117919922]]
# Learned weight:1.5397,learned bias:0.0801
# Predictions for [[4.0], [7.0]]:[[6.239021301269531], [10.858175277709961]]
# Learned weight:4.6771,learned bias:0.4977
# Predictions for [[4.0], [7.0]]:[[19.206207275390625], [33.23761749267578]]
# Learned weight:6.2372,learned bias:0.6982
# Predictions for [[4.0], [7.0]]:[[25.647022247314453], [44.358665466308594]]
# Learned weight:5.1010,learned bias:0.5167
# Predictions for [[4.0], [7.0]]:[[20.920923233032227], [36.22406768798828]]
# Learned weight:2.0872,learned bias:0.0742
# Predictions for [[4.0], [7.0]]:[[8.422825813293457], [14.684306144714355]]
# Learned weight:-0.6372,learned bias:-0.3097
# Predictions for [[4.0], [7.0]]:[[-2.858384847640991], [-4.769908428192139]]
# Learned weight:-1.1146,learned bias:-0.3461
# Predictions for [[4.0], [7.0]]:[[-4.804405689239502], [-8.14809799194336]]
# Learned weight:0.9948,learned bias:0.0148
# Predictions for [[4.0], [7.0]]:[[3.9940197467803955], [6.978450775146484]]
# Learned weight:4.1688,learned bias:0.5483
# Predictions for [[4.0], [7.0]]:[[17.223554611206055], [29.730026245117188]]
# Learned weight:6.1181,learned bias:0.9162
# Predictions for [[4.0], [7.0]]:[[25.38857650756836], [43.74287796020508]]
# Learned weight:5.4325,learned bias:0.9101
# Predictions for [[4.0], [7.0]]:[[22.640045166015625], [38.937522888183594]]
# Learned weight:2.5953,learned bias:0.6008
# Predictions for [[4.0], [7.0]]:[[10.981858253479004], [18.767650604248047]]
# Learned weight:-0.3644,learned bias:0.2872
# Predictions for [[4.0], [7.0]]:[[-1.1704241037368774], [-2.263679265975952]]
# Learned weight:-1.3307,learned bias:0.2810
# Predictions for [[4.0], [7.0]]:[[-5.0419535636901855], [-9.034192085266113]]
# Learned weight:0.3772,learned bias:0.6820
# Predictions for [[4.0], [7.0]]:[[2.19062876701355], [3.3221304416656494]]
# Learned weight:3.5157,learned bias:1.3058
# Predictions for [[4.0], [7.0]]:[[15.368532180786133], [25.915565490722656]]
# Learned weight:5.8111,learned bias:1.8163
# Predictions for [[4.0], [7.0]]:[[25.060653686523438], [42.49388122558594]]
# Learned weight:5.5949,learned bias:1.9665
# Predictions for [[4.0], [7.0]]:[[24.345935821533203], [41.130496978759766]]
# Learned weight:3.0037,learned bias:1.7757
# Predictions for [[4.0], [7.0]]:[[13.790553092956543], [22.80173110961914]]
# Learned weight:-0.1186,learned bias:1.5149
# Predictions for [[4.0], [7.0]]:[[1.040478229522705], [0.6846878528594971]]
# Learned weight:-1.5473,learned bias:1.5115
# Predictions for [[4.0], [7.0]]:[[-4.6775312423706055], [-9.319304466247559]]
# Learned weight:-0.2762,learned bias:1.9130
# Predictions for [[4.0], [7.0]]:[[0.808180570602417], [-0.020439505577087402]]
# Learned weight:2.7584,learned bias:2.5802
# Predictions for [[4.0], [7.0]]:[[13.613754272460938], [21.88889503479004]]
# Learned weight:5.3515,learned bias:3.1868
# Predictions for [[4.0], [7.0]]:[[24.592674255371094], [40.64710998535156]]
# Learned weight:5.6151,learned bias:3.4529
# Predictions for [[4.0], [7.0]]:[[25.913375854492188], [42.758697509765625]]
# Learned weight:3.3362,learned bias:3.3463
# Predictions for [[4.0], [7.0]]:[[16.691165924072266], [26.699840545654297]]
# Learned weight:0.1301,learned bias:3.1040
# Predictions for [[4.0], [7.0]]:[[3.6241672039031982], [4.014321804046631]]
# Learned weight:-1.7214,learned bias:3.0616
# Predictions for [[4.0], [7.0]]:[[-3.8241028785705566], [-8.988407135009766]]
# Learned weight:-0.9105,learned bias:3.4112
# Predictions for [[4.0], [7.0]]:[[-0.230926513671875], [-2.9624884128570557]]
# Learned weight:1.9559,learned bias:4.0619
# Predictions for [[4.0], [7.0]]:[[11.885452270507812], [17.753141403198242]]
# Learned weight:4.7929,learned bias:4.7050
# Predictions for [[4.0], [7.0]]:[[23.876544952392578], [38.25517272949219]]
# Learned weight:5.5370,learned bias:5.0351
# Predictions for [[4.0], [7.0]]:[[27.18305206298828], [43.79399490356445]]
# Learned weight:3.6303,learned bias:4.9688
# Predictions for [[4.0], [7.0]]:[[19.49014663696289], [30.381174087524414]]
# Learned weight:0.4220,learned bias:4.7040
# Predictions for [[4.0], [7.0]]:[[6.391928672790527], [7.657878875732422]]
# Learned weight:-1.8023,learned bias:4.5771
# Predictions for [[4.0], [7.0]]:[[-2.6319751739501953], [-8.038768768310547]]
# Learned weight:-1.4636,learned bias:4.8200
# Predictions for [[4.0], [7.0]]:[[-1.0341720581054688], [-5.424832344055176]]
# Learned weight:1.1746,learned bias:5.3931
# Predictions for [[4.0], [7.0]]:[[10.09153938293457], [13.61539077758789]]
# Learned weight:4.1960,learned bias:6.0125
# Predictions for [[4.0], [7.0]]:[[22.796520233154297], [35.3845100402832]]
# Learned weight:5.4098,learned bias:6.3544
# Predictions for [[4.0], [7.0]]:[[27.99347686767578], [44.22282028198242]]
# Learned weight:3.9263,learned bias:6.2865
# Predictions for [[4.0], [7.0]]:[[21.991531372070312], [33.77033615112305]]
# Learned weight:0.7968,learned bias:5.9633
# Predictions for [[4.0], [7.0]]:[[9.150365829467773], [11.540700912475586]]
# Learned weight:-1.7423,learned bias:5.7141
# Predictions for [[4.0], [7.0]]:[[-1.2553291320800781], [-6.4823760986328125]]
# Learned weight:-1.8780,learned bias:5.8058
# Predictions for [[4.0], [7.0]]:[[-1.7061386108398438], [-7.340115547180176]]
# Learned weight:0.4759,learned bias:6.2507
# Predictions for [[4.0], [7.0]]:[[8.15417194366455], [9.581771850585938]]
# Learned weight:3.6163,learned bias:6.7970
# Predictions for [[4.0], [7.0]]:[[21.26230812072754], [32.111324310302734]]
# Learned weight:5.2763,learned bias:7.1097
# Predictions for [[4.0], [7.0]]:[[28.215023040771484], [44.044044494628906]]
# Learned weight:4.2551,learned bias:7.0113
# Predictions for [[4.0], [7.0]]:[[24.031545639038086], [36.796714782714844]]
# Learned weight:1.2816,learned bias:6.6093
# Predictions for [[4.0], [7.0]]:[[11.735509872436523], [15.580205917358398]]
# Learned weight:-1.5095,learned bias:6.2183
# Predictions for [[4.0], [7.0]]:[[0.1803731918334961], [-4.348046779632568]]
# Learned weight:-2.1130,learned bias:6.1341
# Predictions for [[4.0], [7.0]]:[[-2.317780017852783], [-8.656709671020508]]
# Learned weight:-0.0954,learned bias:6.4208
# Predictions for [[4.0], [7.0]]:[[6.039052963256836], [5.75276517868042]]
# Learned weight:3.0933,learned bias:6.8643
# Predictions for [[4.0], [7.0]]:[[19.23771858215332], [28.517763137817383]]
# Learned weight:5.1629,learned bias:7.1269
# Predictions for [[4.0], [7.0]]:[[27.778404235839844], [43.26699447631836]]
# Learned weight:4.6292,learned bias:6.9899
# Predictions for [[4.0], [7.0]]:[[25.506649017333984], [39.394229888916016]]
# Learned weight:1.8822,learned bias:6.5109
# Predictions for [[4.0], [7.0]]:[[14.039528846740723], [19.685985565185547]]
# Learned weight:-1.0951,learned bias:5.9830
# Predictions for [[4.0], [7.0]]:[[1.6027607917785645], [-1.682455062866211]]
# Learned weight:-2.1522,learned bias:5.7240
# Predictions for [[4.0], [7.0]]:[[-2.884873867034912], [-9.341508865356445]]
# Learned weight:-0.5184,learned bias:5.8479
# Predictions for [[4.0], [7.0]]:[[3.774465560913086], [2.2193655967712402]]
# Learned weight:2.6435,learned bias:6.1839
# Predictions for [[4.0], [7.0]]:[[16.758020401000977], [24.688617706298828]]
# Learned weight:5.0730,learned bias:6.3989
# Predictions for [[4.0], [7.0]]:[[26.69098663330078], [41.91002655029297]]
# Learned weight:5.0377,learned bias:6.2381
# Predictions for [[4.0], [7.0]]:[[26.388771057128906], [41.501766204833984]]
# Learned weight:2.5790,learned bias:5.7083
# Predictions for [[4.0], [7.0]]:[[16.02413558959961], [23.76101303100586]]
# Learned weight:-0.5176,learned bias:5.0737
# Predictions for [[4.0], [7.0]]:[[3.0031700134277344], [1.4502418041229248]]
# Learned weight:-2.0068,learned bias:4.6666
# Predictions for [[4.0], [7.0]]:[[-3.360732078552246], [-9.381223678588867]]
# Learned weight:-0.7983,learned bias:4.6486
# Predictions for [[4.0], [7.0]]:[[1.4554669857025146], [-0.9394011497497559]]
# Learned weight:2.2591,learned bias:4.8955
# Predictions for [[4.0], [7.0]]:[[13.931861877441406], [20.709115982055664]]
# Learned weight:4.9876,learned bias:5.0869
# Predictions for [[4.0], [7.0]]:[[25.03728485107422], [40.00004577636719]]
# Learned weight:5.4467,learned bias:4.9375
# Predictions for [[4.0], [7.0]]:[[26.72453498840332], [43.064781188964844]]
# Learned weight:3.3288,learned bias:4.4030
# Predictions for [[4.0], [7.0]]:[[17.717975616455078], [27.70424461364746]]
# Learned weight:0.1797,learned bias:3.7124
# Predictions for [[4.0], [7.0]]:[[4.431238651275635], [4.970386505126953]]
# Learned weight:-1.7124,learned bias:3.2045
# Predictions for [[4.0], [7.0]]:[[-3.64497709274292], [-8.78207778930664]]
# Learned weight:-0.9632,learned bias:3.0847
# Predictions for [[4.0], [7.0]]:[[-0.7680191993713379], [-3.657524824142456]]
# Learned weight:1.9123,learned bias:3.2780
# Predictions for [[4.0], [7.0]]:[[10.927083969116211], [16.663917541503906]]
# Learned weight:4.8699,learned bias:3.4839
# Predictions for [[4.0], [7.0]]:[[22.9633846282959], [37.572975158691406]]
# Learned weight:5.8064,learned bias:3.3933
# Predictions for [[4.0], [7.0]]:[[26.61870574951172], [44.03776931762695]]
# Learned weight:4.0719,learned bias:2.9112
# Predictions for [[4.0], [7.0]]:[[19.19869041442871], [31.414274215698242]]
# Learned weight:0.9371,learned bias:2.2264
# Predictions for [[4.0], [7.0]]:[[5.974808692932129], [8.786131858825684]]
# Learned weight:-1.3205,learned bias:1.6758
# Predictions for [[4.0], [7.0]]:[[-3.606407642364502], [-7.56805419921875]]
# Learned weight:-1.0550,learned bias:1.5034
# Predictions for [[4.0], [7.0]]:[[-2.7167372703552246], [-5.881839275360107]]
# Learned weight:1.5645,learned bias:1.6853
# Predictions for [[4.0], [7.0]]:[[7.9433794021606445], [12.636963844299316]]
# Learned weight:4.6753,learned bias:1.9475
# Predictions for [[4.0], [7.0]]:[[20.64886474609375], [34.674888610839844]]
# Learned weight:6.0605,learned bias:1.9639
# Predictions for [[4.0], [7.0]]:[[26.205934524536133], [44.38743209838867]]
# Learned weight:4.7432,learned bias:1.5913
# Predictions for [[4.0], [7.0]]:[[20.564254760742188], [34.7939453125]]
# Learned weight:1.6893,learned bias:0.9730
# Predictions for [[4.0], [7.0]]:[[7.730090141296387], [12.797874450683594]]
# Learned weight:-0.8878,learned bias:0.4365
# Predictions for [[4.0], [7.0]]:[[-3.1146421432495117], [-5.778001308441162]]
# Learned weight:-1.1185,learned bias:0.2583
# Predictions for [[4.0], [7.0]]:[[-4.215506553649902], [-7.570862770080566]]
# Learned weight:1.1780,learned bias:0.4658
# Predictions for [[4.0], [7.0]]:[[5.17789888381958], [8.711971282958984]]
# Learned weight:4.3636,learned bias:0.8179
# Predictions for [[4.0], [7.0]]:[[18.272480010986328], [31.36338996887207]]
# Learned weight:6.1596,learned bias:0.9790
# Predictions for [[4.0], [7.0]]:[[25.617218017578125], [44.09587097167969]]
# Learned weight:5.2849,learned bias:0.7605
# Predictions for [[4.0], [7.0]]:[[21.90021514892578], [37.75497817993164]]
# Learned weight:2.3780,learned bias:0.2571
# Predictions for [[4.0], [7.0]]:[[9.76901626586914], [16.902950286865234]]
# Learned weight:-0.4630,learned bias:-0.2213
# Predictions for [[4.0], [7.0]]:[[-2.0733258724212646], [-3.4623324871063232]]
# Learned weight:-1.1888,learned bias:-0.3721
# Predictions for [[4.0], [7.0]]:[[-5.127114772796631], [-8.693405151367188]]
# Learned weight:0.7271,learned bias:-0.1172
# Predictions for [[4.0], [7.0]]:[[2.79133677482605], [4.97277307510376]]
# Learned weight:3.9097,learned bias:0.3404
# Predictions for [[4.0], [7.0]]:[[15.979324340820312], [27.70853042602539]]
# Learned weight:6.0714,learned bias:0.6633
# Predictions for [[4.0], [7.0]]:[[24.949005126953125], [43.16326141357422]]
